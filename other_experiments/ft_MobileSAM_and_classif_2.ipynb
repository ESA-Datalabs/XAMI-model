# %%
import os
os.environ['CUDA_LAUNCH_BLOCKING'] = "1"
os.environ['PYTORCH_NO_CUDA_MEMORY_CACHING'] = "1"

from pathlib import Path
import matplotlib.pyplot as plt
import cv2
import torch
from torch import cuda
import os
import numpy as np
import random
from PIL import Image
import matplotlib.colors as mcolors
import numpy.ma as ma
import json
from matplotlib.path import Path
import math
from pycocotools import mask as maskUtils
from torch.optim.lr_scheduler import StepLR, LambdaLR

np.set_printoptions(precision=15)

torch.backends.cudnn.deterministic = True
random.seed(42)
np.random.seed(42)
torch.manual_seed(42)
torch.cuda.manual_seed_all(42)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

torch.cuda.set_device(3) # can save errors 

import class_agnostic_sam_predictor, dataset, losses
from class_agnostic_sam_predictor import predictor_utils as predict
from dataset import dataset_utils, augment, astronomy_utils 
from losses import loss as loss

global batch_idx
# # Dataset split

# You can choose to manually split your dataset here (if you don't have (at least) train/val splits locally). Otherwise, you should set this variable to `False`. All masks are converted to Run Length Enconding (RLE) format for computational efficiency, especially given that many masks are small.

# %%
split_dataset_here = False

# %%
if split_dataset_here:
    input_dir = './roboflow_datasets/xmm_om_artefacts_512-3-COCO/train/'
    json_file_path = input_dir+'_annotations.coco.json'
    
    # COCO segmentation bboxes are in XYWH format
    with open(json_file_path) as f:
        data = json.load(f)
        
    ground_truth_masks, bbox_coords, classes, class_categories = dataset_utils.get_coords_and_masks_from_json(input_dir, data) # type: ignore

    # check if some images lack annotations due to eventual filtering by mask size or classes (this usually doesn't happen)
    raw_images = [input_dir+img_data['file_name'] for img_data in data['images']]
    training_size, val_size, test_size = (0.7, 0.2, 0.1)
    splits = dataset_utils.split_list(raw_images, [training_size, val_size, test_size])
    training_image_paths, val_image_paths, test_image_paths = splits[0], splits[1], splits[2]
    train_gt_masks, train_bboxes = dataset_utils.create_dataset(training_image_paths, ground_truth_masks, bbox_coords)
    test_gt_masks, test_bboxes = dataset_utils.create_dataset(test_image_paths, ground_truth_masks, bbox_coords)
    val_gt_masks, val_bboxes = dataset_utils.create_dataset(val_image_paths, ground_truth_masks, bbox_coords)
    
    del ground_truth_masks, bbox_coords

else: # assume you already have a train/val/test split directory
    train_dir = './roboflow_datasets/xmm_om_artefacts_512-3-COCO/train/'
    valid_dir = './roboflow_datasets/xmm_om_artefacts_512-3-COCO/valid/'
    test_dir =  './roboflow_datasets/xmm_om_artefacts_512-3-COCO/test/' # in case test split is also available
    json_train_path, json_valid_path, json_test_path = train_dir+'_annotations.coco.json', valid_dir+'_annotations.coco.json', test_dir+'_annotations.coco.json'
    
    training_image_paths = [train_dir+filename for filename in os.listdir(train_dir) 
                            if any(filename.lower().endswith(ext) for ext in ['.png', '.jpg', '.jpeg']) ]
    val_image_paths = [valid_dir+filename for filename in os.listdir(valid_dir) 
                       if any(filename.lower().endswith(ext) for ext in ['.png', '.jpg', '.jpeg']) ]
    test_image_paths = [test_dir+filename for filename in os.listdir(test_dir) 
                        if any(filename.lower().endswith(ext) for ext in ['.png', '.jpg', '.jpeg']) ]
    
    train_data = dataset_utils.load_json(json_train_path)
    valid_data = dataset_utils.load_json(json_valid_path)
    test_data = dataset_utils.load_json(json_test_path)
        
    train_gt_masks, train_bboxes, train_classes, train_class_categories = dataset_utils.get_coords_and_masks_from_json(train_dir, train_data) # type: ignore
    val_gt_masks, val_bboxes, val_classes, val_class_categories = dataset_utils.get_coords_and_masks_from_json(valid_dir, valid_data) # type: ignore
    test_gt_masks, test_bboxes, test_classes, test_class_categories = dataset_utils.get_coords_and_masks_from_json(test_dir, test_data) # type: ignore

# %%
print('# dataset images: \ntrain', len(training_image_paths), '\nvalid', len(val_image_paths), '\ntest', len(test_image_paths))


# **Visualize annotations**
# Out:
# # dataset images:
# train 1136
# valid 289
# test 1

# %%
for one_path in training_image_paths[:4]:
    image_id2 = one_path.split('/')[-1]
    print(image_id2)
    image_masks_ids = [key for key in train_gt_masks.keys() if key.startswith(image_id2)]
    image_ = cv2.imread(one_path)
    image_ = cv2.cvtColor(image_, cv2.COLOR_BGR2RGB)
    plt.figure(figsize=(8,8))
    plt.imshow(image_)
    for name in image_masks_ids:
        dataset_utils.show_box(train_bboxes[name], plt.gca())
        dataset_utils.show_mask(maskUtils.decode(train_gt_masks[name]), plt.gca())
    plt.axis('off')
    plt.show()
    plt.close()


# # Augmentation
# 
# This algorithm performs augmentations and updates the negative masks in the case of a geometric transformations. Otherwise, it masks the result of a noise/blur transformation given the mask of the initial image. 
# 
# 📍 For augmentation, the bboxes are expected to be in the XYWH format, not XYXY format (used by SAM). However, the SAM AMG generated results are in the XYWH format (converted from XYXY).
#
# Out:
# S0692931401_M_png.rf.31be402b136e09afbfed5fa5db7447bb.jpg
# S0300961001_B_png.rf.1e0ee87e6e6fbf4891115ab7626abcca.jpg
# S0611182401_L_png.rf.4d7d3d8b3ab5b090e1ef7c9d7024f22a.jpg
# S0553911001_L_png.rf.626429978cc8aaf564ad66114752de9d.jpg

# %%
use_augmentation = False # set this to False if you already have an augmented dataset

if use_augmentation: 

    # remove augmented images possibly resulted from a previous augmentation run
    import os
    import glob
    import albumentations as A
    import math
    
    files = glob.glob(f'{input_dir}/*augm*')
    
    for file in files:
        os.remove(file)

    geometrical_augmentations = A.Compose([
        A.Flip(),
        A.RandomRotate90(),
        A.RandomSizedCrop((512 - 50, 512 - 50), 512, 512),
    ], bbox_params={'format':'coco', 'label_fields': ['category_id']}, p=1)
    
    noise_blur_augmentations = A.Compose([
        A.GaussianBlur(blur_limit=(3, 3), p=0.6),
        A.GaussNoise(var_limit=(10.0, 50.0), p=0.8),
        A.ISONoise(p=0.8),
    ], bbox_params={'format':'coco', 'label_fields': ['category_id']}, p=1)
    
    image_paths = []
    for image_path in training_image_paths:
        image_paths.append(image_path)
        image_ = cv2.imread(image_path)
        image_ = cv2.cvtColor(image_, cv2.COLOR_BGR2RGB)
        image_size = (image_.shape[0], image_.shape[1])
        masks = [value_i for key_i, value_i in train_gt_masks.items() if image_path.split('/')[-1] in key_i]
        bboxes_ = [augment.enlarge_bbox(np.array([value_i[0], math.floor(value_i[1]),  math.floor(value_i[2] - value_i[0]), \
                                        math.floor(value_i[3] - value_i[1])]), 2, image_size) \
                                        for key_i, value_i in train_bboxes.items() if image_path.split('/')[-1] in key_i]   
        label_ids = [classes[key_i] for key_i, value_i in train_bboxes.items() if image_path.split('/')[-1] in key_i]
    
        image_size = (image_.shape[0], image_.shape[1])
        for bbox in bboxes_:
            if bbox[2] <= 1 or bbox[3] <= 1:
                print("Invalid bbox detected:", bbox)
            
        if len(bboxes_) != len(masks):
            print('len(bboxes_) != len(masks)', len(bboxes_), len(masks))
            continue
    
        if len(bboxes_) != len(label_ids):
            print('len(bboxes_) != len(label_ids)', len(bboxes_), len(label_ids))
            continue
    
        if len(bboxes_) == 0:
            print(f'{image_path} has no bounding boxes.')
            
        img_negative_mask = (image_>0).astype(int)
        
        # the geometrical augm doesn't change the shape of the image
        augmented1 = augment.augment_and_show(geometrical_augmentations, image_, masks, bboxes_, label_ids, class_categories, show_=False)
        new_image_negative_mask = (augmented1['image']>0).astype(int) # to mask the transform which is derived from the geometric transform
        augmented3 = augment.augment_and_show(noise_blur_augmentations, image_, masks, bboxes_, label_ids, class_categories, show_=False)
    
        # mask the transform using the image negative mask
        augmented3['image'] = augmented3['image'] * img_negative_mask
            
        new_filename1 = image_path.replace('.'+image_path.split('.')[-1], '_augm1.jpg')
        new_filename3 = image_path.replace('.'+image_path.split('.')[-1], '_augm3.jpg')
    
        augment.update_dataset_with_augms(augmented1, new_filename1, train_bboxes, train_gt_masks, image_paths, classes)
        augment.update_dataset_with_augms(augmented3, new_filename3, train_bboxes, train_gt_masks, image_paths, classes)
else:
    image_paths = training_image_paths + val_image_paths + test_image_paths

# **dataset distribution**

# %%
from PIL import Image
import numpy as np

means = []
stds = []

for image_path in image_paths:
    image = Image.open(image_path)

    image_array = np.array(image) / 255.0

    mean = image_array.mean()
    std = image_array.std()

    means.append(mean)
    stds.append(std)

means = np.array(means)
stds = np.array(stds)

# %%
np.mean(means), np.std(means)
# Out:
# (0.14676384884011012, 0.12032532066821507)

# %%
np.mean(stds),np.std(stds)


# ## 🚀 Prepare Mobile SAM Fine Tuning
# Out:
# (0.10197050625939277, 0.03395824708962004)

# %%
# !nvidia-smi

# %%
import sys
import PIL
from PIL import Image
sys.path.append('/workspace/raid/OM_DeepLearning/MobileSAM-fine-tuning/')
from ft_mobile_sam import sam_model_registry, SamPredictor

mobile_sam_checkpoint = "/workspace/raid/OM_DeepLearning/MobileSAM-fine-tuning/weights/sam_vit_h_4b8939.pth"
# mobile_sam_checkpoint = "./ft_mobile_sam_final.pth"
device = "cuda:1" if torch.cuda.is_available() else "cpu"
mobile_sam_model = sam_model_registry["vit_h"](checkpoint=mobile_sam_checkpoint)
mobile_sam_model.to(device);
print("DEVICE", device)
# Out:
# /workspace/raid/OM_DeepLearning/MobileSAM-fine-tuning/ft_mobile_sam/modeling/tiny_vit_sam.py:656: UserWarning: Overwriting tiny_vit_5m_224 in registry with ft_mobile_sam.modeling.tiny_vit_sam.tiny_vit_5m_224. This is because the name being registered conflicts with an existing name. Please check if this is not expected.
#   return register_model(fn_wrapper)
# /workspace/raid/OM_DeepLearning/MobileSAM-fine-tuning/ft_mobile_sam/modeling/tiny_vit_sam.py:656: UserWarning: Overwriting tiny_vit_11m_224 in registry with ft_mobile_sam.modeling.tiny_vit_sam.tiny_vit_11m_224. This is because the name being registered conflicts with an existing name. Please check if this is not expected.
#   return register_model(fn_wrapper)
# /workspace/raid/OM_DeepLearning/MobileSAM-fine-tuning/ft_mobile_sam/modeling/tiny_vit_sam.py:656: UserWarning: Overwriting tiny_vit_21m_224 in registry with ft_mobile_sam.modeling.tiny_vit_sam.tiny_vit_21m_224. This is because the name being registered conflicts with an existing name. Please check if this is not expected.
#   return register_model(fn_wrapper)
# /workspace/raid/OM_DeepLearning/MobileSAM-fine-tuning/ft_mobile_sam/modeling/tiny_vit_sam.py:656: UserWarning: Overwriting tiny_vit_21m_384 in registry with ft_mobile_sam.modeling.tiny_vit_sam.tiny_vit_21m_384. This is because the name being registered conflicts with an existing name. Please check if this is not expected.
#   return register_model(fn_wrapper)
# /workspace/raid/OM_DeepLearning/MobileSAM-fine-tuning/ft_mobile_sam/modeling/tiny_vit_sam.py:656: UserWarning: Overwriting tiny_vit_21m_512 in registry with ft_mobile_sam.modeling.tiny_vit_sam.tiny_vit_21m_512. This is because the name being registered conflicts with an existing name. Please check if this is not expected.
#   return register_model(fn_wrapper)
# /opt/conda/envs/env_py311/lib/python3.11/site-packages/mobile_sam/modeling/tiny_vit_sam.py:656: UserWarning: Overwriting tiny_vit_5m_224 in registry with mobile_sam.modeling.tiny_vit_sam.tiny_vit_5m_224. This is because the name being registered conflicts with an existing name. Please check if this is not expected.
#   return register_model(fn_wrapper)
# /opt/conda/envs/env_py311/lib/python3.11/site-packages/mobile_sam/modeling/tiny_vit_sam.py:656: UserWarning: Overwriting tiny_vit_11m_224 in registry with mobile_sam.modeling.tiny_vit_sam.tiny_vit_11m_224. This is because the name being registered conflicts with an existing name. Please check if this is not expected.
#   return register_model(fn_wrapper)
# /opt/conda/envs/env_py311/lib/python3.11/site-packages/mobile_sam/modeling/tiny_vit_sam.py:656: UserWarning: Overwriting tiny_vit_21m_224 in registry with mobile_sam.modeling.tiny_vit_sam.tiny_vit_21m_224. This is because the name being registered conflicts with an existing name. Please check if this is not expected.
#   return register_model(fn_wrapper)
# /opt/conda/envs/env_py311/lib/python3.11/site-packages/mobile_sam/modeling/tiny_vit_sam.py:656: UserWarning: Overwriting tiny_vit_21m_384 in registry with mobile_sam.modeling.tiny_vit_sam.tiny_vit_21m_384. This is because the name being registered conflicts with an existing name. Please check if this is not expected.
#   return register_model(fn_wrapper)
# /opt/conda/envs/env_py311/lib/python3.11/site-packages/mobile_sam/modeling/tiny_vit_sam.py:656: UserWarning: Overwriting tiny_vit_21m_512 in registry with mobile_sam.modeling.tiny_vit_sam.tiny_vit_21m_512. This is because the name being registered conflicts with an existing name. Please check if this is not expected.
#   return register_model(fn_wrapper)
# DEVICE cuda:1

# %%
use_wandb = False

if use_wandb:
    from datetime import datetime
    # !pip install wandb
    # !wandb login --relogin
    import wandb
    wandb.login()
    run = wandb.init(project="OM_AI_v1", name=f"yolo_sam {datetime.now()}")

    wandb.watch(mobile_sam_model, log='all', log_graph=True)


# ## Convert the input images into a format SAM's internal functions expect.

# %%
# Preprocess the images
import os
from collections import defaultdict
import torch
import segment_anything
from segment_anything.utils.transforms import ResizeLongestSide
from torchvision.transforms.functional import resize

transform = ResizeLongestSide(mobile_sam_model.image_encoder.img_size)

def transform_image(image, k):
       
        # sets a specific mean for each image
        image_T = np.transpose(image, (2, 1, 0))
        mean_ = np.mean(image_T[image_T>0])
        std_ = np.std(image_T[image_T>0]) 
        pixel_mean = torch.as_tensor([mean_, mean_, mean_], dtype=torch.float, device=device)
        pixel_std = torch.as_tensor([std_, std_, std_], dtype=torch.float, device=device)

        mobile_sam_model.register_buffer("pixel_mean", torch.Tensor(pixel_mean).unsqueeze(-1).unsqueeze(-1), False) # not in SAM
        mobile_sam_model.register_buffer("pixel_std", torch.Tensor(pixel_std).unsqueeze(-1).unsqueeze(-1), False) # not in SAM

        transformed_data = {}
        negative_mask = np.where(image > 0, True, False)
        negative_mask = torch.from_numpy(negative_mask)  
        negative_mask = negative_mask.permute(2, 0, 1)
        negative_mask = resize(negative_mask, [1024, 1024], antialias=True) 
        negative_mask = negative_mask.unsqueeze(0)
        # scales the image to 1024x1024 by longest side 
        input_image = transform.apply_image(image)
        input_image_torch = torch.as_tensor(input_image, device=device)
        transformed_image = input_image_torch.permute(2, 0, 1).contiguous()[None, :, :, :]
        
        # normalization and padding
        input_image = mobile_sam_model.preprocess(transformed_image)
        original_image_size = image.shape[:2]
        input_size = tuple(transformed_image.shape[-2:])
        input_image[~negative_mask] = 0
        transformed_data['image'] = input_image.clone() 
        transformed_data['input_size'] = input_size 
        transformed_data['image_id'] = k
        transformed_data['original_image_size'] = original_image_size
    
        return transformed_data

# %%
from torch.utils.data import Dataset
from PIL import Image
from torch.utils.data import DataLoader

class ImageDataset(Dataset):
    def __init__(self, image_paths, bbox_coords, gt_masks, transform=None):
        self.image_paths = image_paths
        self.transform = transform
        
    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        img_id = self.image_paths[idx].split("/")[-1]
        image = cv2.imread(self.image_paths[idx])
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) 

        if self.transform is not None:
            return self.transform(image, img_id)
        else:
            print("❗️No transform❗️")
            return image
        
batch_size = 2

train_set = ImageDataset(training_image_paths[:10], train_bboxes, train_gt_masks, transform_image) 
val_set = ImageDataset(val_image_paths[:5], val_bboxes, val_gt_masks, transform_image) 
test_set = ImageDataset(test_image_paths, test_bboxes, test_gt_masks, transform_image) 

train_dataloader = DataLoader(train_set, batch_size=batch_size, shuffle=True)
val_dataloader = DataLoader(val_set, batch_size=batch_size, shuffle=False)
test_dataloader = DataLoader(test_set, batch_size=batch_size, shuffle=False)

# %%
import torch.nn.functional as F
from torch.optim.lr_scheduler import CosineAnnealingLR
import matplotlib.pyplot as plt
import torch.nn as nn

lr=3e-4 # Sam paper uses 256 batch size on 256 GPUs
wd=0.00005
loss_scaling_factor = 1e5 # this factor is used to save some very small gradients 

parameters_to_optimize = [param for param in mobile_sam_model.mask_decoder.parameters() if param.requires_grad]
optimizer = torch.optim.AdamW(parameters_to_optimize, lr=lr, weight_decay=wd, betas=(0.9, 0.999))
predictor = SamPredictor(mobile_sam_model)

# LR scheduler
base_lr = 8e-4/16
steps_per_epoch = len(train_dataloader)
scheduler = StepLR(optimizer, step_size=4*steps_per_epoch, gamma=0.1)

# Warmup logic
warmup_iters = 250/16
lambda_lr = lambda iter: iter / warmup_iters * base_lr if iter < warmup_iters else base_lr * (0.1 ** ((iter // (60000/16)) + (iter // (86666/16))))
scheduler_warmup = LambdaLR(optimizer, lr_lambda=lambda_lr)

# ## Model weights

# %%
for name, param in mobile_sam_model.named_parameters():
    if 'mask_decoder' in name:
        param.requires_grad = True
    else:
        param.requires_grad = False

# %%
def check_requires_grad(model, show=True):
    for name, param in model.named_parameters():
        if param.requires_grad and show:
            print("✅ Param", name, " requires grad.")
        elif param.requires_grad == False:
            print("❌ Param", name, " doesn't require grad.")

# %%
print(f"🚀 The model has {sum(p.numel() for p in mobile_sam_model.parameters() if p.requires_grad)} trainable parameters.\n")
check_requires_grad(mobile_sam_model)


# ## Run fine tuning
# Out:
# 🚀 The model has 4058340 trainable parameters.
#
# ❌ Param image_encoder.pos_embed  doesn't require grad.
# ❌ Param image_encoder.patch_embed.proj.weight  doesn't require grad.
# ❌ Param image_encoder.patch_embed.proj.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.0.norm1.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.0.norm1.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.0.attn.rel_pos_h  doesn't require grad.
# ❌ Param image_encoder.blocks.0.attn.rel_pos_w  doesn't require grad.
# ❌ Param image_encoder.blocks.0.attn.qkv.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.0.attn.qkv.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.0.attn.proj.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.0.attn.proj.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.0.norm2.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.0.norm2.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.0.mlp.lin1.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.0.mlp.lin1.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.0.mlp.lin2.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.0.mlp.lin2.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.1.norm1.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.1.norm1.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.1.attn.rel_pos_h  doesn't require grad.
# ❌ Param image_encoder.blocks.1.attn.rel_pos_w  doesn't require grad.
# ❌ Param image_encoder.blocks.1.attn.qkv.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.1.attn.qkv.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.1.attn.proj.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.1.attn.proj.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.1.norm2.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.1.norm2.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.1.mlp.lin1.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.1.mlp.lin1.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.1.mlp.lin2.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.1.mlp.lin2.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.2.norm1.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.2.norm1.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.2.attn.rel_pos_h  doesn't require grad.
# ❌ Param image_encoder.blocks.2.attn.rel_pos_w  doesn't require grad.
# ❌ Param image_encoder.blocks.2.attn.qkv.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.2.attn.qkv.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.2.attn.proj.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.2.attn.proj.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.2.norm2.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.2.norm2.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.2.mlp.lin1.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.2.mlp.lin1.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.2.mlp.lin2.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.2.mlp.lin2.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.3.norm1.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.3.norm1.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.3.attn.rel_pos_h  doesn't require grad.
# ❌ Param image_encoder.blocks.3.attn.rel_pos_w  doesn't require grad.
# ❌ Param image_encoder.blocks.3.attn.qkv.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.3.attn.qkv.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.3.attn.proj.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.3.attn.proj.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.3.norm2.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.3.norm2.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.3.mlp.lin1.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.3.mlp.lin1.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.3.mlp.lin2.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.3.mlp.lin2.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.4.norm1.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.4.norm1.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.4.attn.rel_pos_h  doesn't require grad.
# ❌ Param image_encoder.blocks.4.attn.rel_pos_w  doesn't require grad.
# ❌ Param image_encoder.blocks.4.attn.qkv.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.4.attn.qkv.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.4.attn.proj.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.4.attn.proj.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.4.norm2.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.4.norm2.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.4.mlp.lin1.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.4.mlp.lin1.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.4.mlp.lin2.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.4.mlp.lin2.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.5.norm1.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.5.norm1.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.5.attn.rel_pos_h  doesn't require grad.
# ❌ Param image_encoder.blocks.5.attn.rel_pos_w  doesn't require grad.
# ❌ Param image_encoder.blocks.5.attn.qkv.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.5.attn.qkv.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.5.attn.proj.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.5.attn.proj.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.5.norm2.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.5.norm2.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.5.mlp.lin1.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.5.mlp.lin1.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.5.mlp.lin2.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.5.mlp.lin2.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.6.norm1.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.6.norm1.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.6.attn.rel_pos_h  doesn't require grad.
# ❌ Param image_encoder.blocks.6.attn.rel_pos_w  doesn't require grad.
# ❌ Param image_encoder.blocks.6.attn.qkv.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.6.attn.qkv.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.6.attn.proj.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.6.attn.proj.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.6.norm2.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.6.norm2.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.6.mlp.lin1.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.6.mlp.lin1.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.6.mlp.lin2.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.6.mlp.lin2.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.7.norm1.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.7.norm1.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.7.attn.rel_pos_h  doesn't require grad.
# ❌ Param image_encoder.blocks.7.attn.rel_pos_w  doesn't require grad.
# ❌ Param image_encoder.blocks.7.attn.qkv.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.7.attn.qkv.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.7.attn.proj.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.7.attn.proj.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.7.norm2.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.7.norm2.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.7.mlp.lin1.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.7.mlp.lin1.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.7.mlp.lin2.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.7.mlp.lin2.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.8.norm1.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.8.norm1.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.8.attn.rel_pos_h  doesn't require grad.
# ❌ Param image_encoder.blocks.8.attn.rel_pos_w  doesn't require grad.
# ❌ Param image_encoder.blocks.8.attn.qkv.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.8.attn.qkv.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.8.attn.proj.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.8.attn.proj.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.8.norm2.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.8.norm2.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.8.mlp.lin1.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.8.mlp.lin1.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.8.mlp.lin2.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.8.mlp.lin2.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.9.norm1.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.9.norm1.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.9.attn.rel_pos_h  doesn't require grad.
# ❌ Param image_encoder.blocks.9.attn.rel_pos_w  doesn't require grad.
# ❌ Param image_encoder.blocks.9.attn.qkv.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.9.attn.qkv.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.9.attn.proj.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.9.attn.proj.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.9.norm2.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.9.norm2.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.9.mlp.lin1.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.9.mlp.lin1.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.9.mlp.lin2.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.9.mlp.lin2.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.10.norm1.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.10.norm1.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.10.attn.rel_pos_h  doesn't require grad.
# ❌ Param image_encoder.blocks.10.attn.rel_pos_w  doesn't require grad.
# ❌ Param image_encoder.blocks.10.attn.qkv.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.10.attn.qkv.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.10.attn.proj.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.10.attn.proj.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.10.norm2.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.10.norm2.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.10.mlp.lin1.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.10.mlp.lin1.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.10.mlp.lin2.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.10.mlp.lin2.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.11.norm1.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.11.norm1.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.11.attn.rel_pos_h  doesn't require grad.
# ❌ Param image_encoder.blocks.11.attn.rel_pos_w  doesn't require grad.
# ❌ Param image_encoder.blocks.11.attn.qkv.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.11.attn.qkv.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.11.attn.proj.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.11.attn.proj.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.11.norm2.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.11.norm2.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.11.mlp.lin1.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.11.mlp.lin1.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.11.mlp.lin2.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.11.mlp.lin2.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.12.norm1.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.12.norm1.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.12.attn.rel_pos_h  doesn't require grad.
# ❌ Param image_encoder.blocks.12.attn.rel_pos_w  doesn't require grad.
# ❌ Param image_encoder.blocks.12.attn.qkv.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.12.attn.qkv.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.12.attn.proj.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.12.attn.proj.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.12.norm2.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.12.norm2.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.12.mlp.lin1.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.12.mlp.lin1.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.12.mlp.lin2.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.12.mlp.lin2.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.13.norm1.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.13.norm1.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.13.attn.rel_pos_h  doesn't require grad.
# ❌ Param image_encoder.blocks.13.attn.rel_pos_w  doesn't require grad.
# ❌ Param image_encoder.blocks.13.attn.qkv.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.13.attn.qkv.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.13.attn.proj.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.13.attn.proj.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.13.norm2.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.13.norm2.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.13.mlp.lin1.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.13.mlp.lin1.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.13.mlp.lin2.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.13.mlp.lin2.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.14.norm1.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.14.norm1.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.14.attn.rel_pos_h  doesn't require grad.
# ❌ Param image_encoder.blocks.14.attn.rel_pos_w  doesn't require grad.
# ❌ Param image_encoder.blocks.14.attn.qkv.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.14.attn.qkv.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.14.attn.proj.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.14.attn.proj.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.14.norm2.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.14.norm2.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.14.mlp.lin1.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.14.mlp.lin1.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.14.mlp.lin2.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.14.mlp.lin2.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.15.norm1.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.15.norm1.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.15.attn.rel_pos_h  doesn't require grad.
# ❌ Param image_encoder.blocks.15.attn.rel_pos_w  doesn't require grad.
# ❌ Param image_encoder.blocks.15.attn.qkv.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.15.attn.qkv.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.15.attn.proj.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.15.attn.proj.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.15.norm2.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.15.norm2.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.15.mlp.lin1.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.15.mlp.lin1.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.15.mlp.lin2.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.15.mlp.lin2.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.16.norm1.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.16.norm1.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.16.attn.rel_pos_h  doesn't require grad.
# ❌ Param image_encoder.blocks.16.attn.rel_pos_w  doesn't require grad.
# ❌ Param image_encoder.blocks.16.attn.qkv.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.16.attn.qkv.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.16.attn.proj.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.16.attn.proj.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.16.norm2.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.16.norm2.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.16.mlp.lin1.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.16.mlp.lin1.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.16.mlp.lin2.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.16.mlp.lin2.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.17.norm1.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.17.norm1.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.17.attn.rel_pos_h  doesn't require grad.
# ❌ Param image_encoder.blocks.17.attn.rel_pos_w  doesn't require grad.
# ❌ Param image_encoder.blocks.17.attn.qkv.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.17.attn.qkv.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.17.attn.proj.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.17.attn.proj.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.17.norm2.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.17.norm2.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.17.mlp.lin1.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.17.mlp.lin1.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.17.mlp.lin2.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.17.mlp.lin2.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.18.norm1.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.18.norm1.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.18.attn.rel_pos_h  doesn't require grad.
# ❌ Param image_encoder.blocks.18.attn.rel_pos_w  doesn't require grad.
# ❌ Param image_encoder.blocks.18.attn.qkv.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.18.attn.qkv.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.18.attn.proj.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.18.attn.proj.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.18.norm2.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.18.norm2.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.18.mlp.lin1.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.18.mlp.lin1.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.18.mlp.lin2.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.18.mlp.lin2.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.19.norm1.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.19.norm1.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.19.attn.rel_pos_h  doesn't require grad.
# ❌ Param image_encoder.blocks.19.attn.rel_pos_w  doesn't require grad.
# ❌ Param image_encoder.blocks.19.attn.qkv.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.19.attn.qkv.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.19.attn.proj.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.19.attn.proj.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.19.norm2.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.19.norm2.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.19.mlp.lin1.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.19.mlp.lin1.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.19.mlp.lin2.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.19.mlp.lin2.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.20.norm1.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.20.norm1.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.20.attn.rel_pos_h  doesn't require grad.
# ❌ Param image_encoder.blocks.20.attn.rel_pos_w  doesn't require grad.
# ❌ Param image_encoder.blocks.20.attn.qkv.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.20.attn.qkv.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.20.attn.proj.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.20.attn.proj.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.20.norm2.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.20.norm2.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.20.mlp.lin1.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.20.mlp.lin1.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.20.mlp.lin2.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.20.mlp.lin2.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.21.norm1.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.21.norm1.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.21.attn.rel_pos_h  doesn't require grad.
# ❌ Param image_encoder.blocks.21.attn.rel_pos_w  doesn't require grad.
# ❌ Param image_encoder.blocks.21.attn.qkv.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.21.attn.qkv.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.21.attn.proj.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.21.attn.proj.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.21.norm2.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.21.norm2.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.21.mlp.lin1.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.21.mlp.lin1.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.21.mlp.lin2.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.21.mlp.lin2.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.22.norm1.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.22.norm1.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.22.attn.rel_pos_h  doesn't require grad.
# ❌ Param image_encoder.blocks.22.attn.rel_pos_w  doesn't require grad.
# ❌ Param image_encoder.blocks.22.attn.qkv.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.22.attn.qkv.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.22.attn.proj.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.22.attn.proj.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.22.norm2.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.22.norm2.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.22.mlp.lin1.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.22.mlp.lin1.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.22.mlp.lin2.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.22.mlp.lin2.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.23.norm1.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.23.norm1.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.23.attn.rel_pos_h  doesn't require grad.
# ❌ Param image_encoder.blocks.23.attn.rel_pos_w  doesn't require grad.
# ❌ Param image_encoder.blocks.23.attn.qkv.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.23.attn.qkv.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.23.attn.proj.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.23.attn.proj.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.23.norm2.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.23.norm2.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.23.mlp.lin1.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.23.mlp.lin1.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.23.mlp.lin2.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.23.mlp.lin2.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.24.norm1.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.24.norm1.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.24.attn.rel_pos_h  doesn't require grad.
# ❌ Param image_encoder.blocks.24.attn.rel_pos_w  doesn't require grad.
# ❌ Param image_encoder.blocks.24.attn.qkv.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.24.attn.qkv.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.24.attn.proj.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.24.attn.proj.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.24.norm2.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.24.norm2.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.24.mlp.lin1.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.24.mlp.lin1.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.24.mlp.lin2.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.24.mlp.lin2.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.25.norm1.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.25.norm1.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.25.attn.rel_pos_h  doesn't require grad.
# ❌ Param image_encoder.blocks.25.attn.rel_pos_w  doesn't require grad.
# ❌ Param image_encoder.blocks.25.attn.qkv.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.25.attn.qkv.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.25.attn.proj.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.25.attn.proj.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.25.norm2.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.25.norm2.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.25.mlp.lin1.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.25.mlp.lin1.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.25.mlp.lin2.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.25.mlp.lin2.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.26.norm1.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.26.norm1.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.26.attn.rel_pos_h  doesn't require grad.
# ❌ Param image_encoder.blocks.26.attn.rel_pos_w  doesn't require grad.
# ❌ Param image_encoder.blocks.26.attn.qkv.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.26.attn.qkv.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.26.attn.proj.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.26.attn.proj.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.26.norm2.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.26.norm2.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.26.mlp.lin1.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.26.mlp.lin1.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.26.mlp.lin2.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.26.mlp.lin2.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.27.norm1.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.27.norm1.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.27.attn.rel_pos_h  doesn't require grad.
# ❌ Param image_encoder.blocks.27.attn.rel_pos_w  doesn't require grad.
# ❌ Param image_encoder.blocks.27.attn.qkv.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.27.attn.qkv.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.27.attn.proj.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.27.attn.proj.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.27.norm2.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.27.norm2.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.27.mlp.lin1.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.27.mlp.lin1.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.27.mlp.lin2.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.27.mlp.lin2.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.28.norm1.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.28.norm1.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.28.attn.rel_pos_h  doesn't require grad.
# ❌ Param image_encoder.blocks.28.attn.rel_pos_w  doesn't require grad.
# ❌ Param image_encoder.blocks.28.attn.qkv.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.28.attn.qkv.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.28.attn.proj.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.28.attn.proj.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.28.norm2.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.28.norm2.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.28.mlp.lin1.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.28.mlp.lin1.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.28.mlp.lin2.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.28.mlp.lin2.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.29.norm1.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.29.norm1.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.29.attn.rel_pos_h  doesn't require grad.
# ❌ Param image_encoder.blocks.29.attn.rel_pos_w  doesn't require grad.
# ❌ Param image_encoder.blocks.29.attn.qkv.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.29.attn.qkv.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.29.attn.proj.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.29.attn.proj.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.29.norm2.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.29.norm2.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.29.mlp.lin1.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.29.mlp.lin1.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.29.mlp.lin2.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.29.mlp.lin2.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.30.norm1.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.30.norm1.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.30.attn.rel_pos_h  doesn't require grad.
# ❌ Param image_encoder.blocks.30.attn.rel_pos_w  doesn't require grad.
# ❌ Param image_encoder.blocks.30.attn.qkv.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.30.attn.qkv.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.30.attn.proj.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.30.attn.proj.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.30.norm2.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.30.norm2.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.30.mlp.lin1.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.30.mlp.lin1.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.30.mlp.lin2.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.30.mlp.lin2.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.31.norm1.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.31.norm1.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.31.attn.rel_pos_h  doesn't require grad.
# ❌ Param image_encoder.blocks.31.attn.rel_pos_w  doesn't require grad.
# ❌ Param image_encoder.blocks.31.attn.qkv.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.31.attn.qkv.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.31.attn.proj.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.31.attn.proj.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.31.norm2.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.31.norm2.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.31.mlp.lin1.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.31.mlp.lin1.bias  doesn't require grad.
# ❌ Param image_encoder.blocks.31.mlp.lin2.weight  doesn't require grad.
# ❌ Param image_encoder.blocks.31.mlp.lin2.bias  doesn't require grad.
# ❌ Param image_encoder.neck.0.weight  doesn't require grad.
# ❌ Param image_encoder.neck.1.weight  doesn't require grad.
# ❌ Param image_encoder.neck.1.bias  doesn't require grad.
# ❌ Param image_encoder.neck.2.weight  doesn't require grad.
# ❌ Param image_encoder.neck.3.weight  doesn't require grad.
# ❌ Param image_encoder.neck.3.bias  doesn't require grad.
# ❌ Param prompt_encoder.point_embeddings.0.weight  doesn't require grad.
# ❌ Param prompt_encoder.point_embeddings.1.weight  doesn't require grad.
# ❌ Param prompt_encoder.point_embeddings.2.weight  doesn't require grad.
# ❌ Param prompt_encoder.point_embeddings.3.weight  doesn't require grad.
# ❌ Param prompt_encoder.not_a_point_embed.weight  doesn't require grad.
# ❌ Param prompt_encoder.mask_downscaling.0.weight  doesn't require grad.
# ❌ Param prompt_encoder.mask_downscaling.0.bias  doesn't require grad.
# ❌ Param prompt_encoder.mask_downscaling.1.weight  doesn't require grad.
# ❌ Param prompt_encoder.mask_downscaling.1.bias  doesn't require grad.
# ❌ Param prompt_encoder.mask_downscaling.3.weight  doesn't require grad.
# ❌ Param prompt_encoder.mask_downscaling.3.bias  doesn't require grad.
# ❌ Param prompt_encoder.mask_downscaling.4.weight  doesn't require grad.
# ❌ Param prompt_encoder.mask_downscaling.4.bias  doesn't require grad.
# ❌ Param prompt_encoder.mask_downscaling.6.weight  doesn't require grad.
# ❌ Param prompt_encoder.mask_downscaling.6.bias  doesn't require grad.
# ❌ Param prompt_encoder.no_mask_embed.weight  doesn't require grad.
# ✅ Param mask_decoder.transformer.layers.0.self_attn.q_proj.weight  requires grad.
# ✅ Param mask_decoder.transformer.layers.0.self_attn.q_proj.bias  requires grad.
# ✅ Param mask_decoder.transformer.layers.0.self_attn.k_proj.weight  requires grad.
# ✅ Param mask_decoder.transformer.layers.0.self_attn.k_proj.bias  requires grad.
# ✅ Param mask_decoder.transformer.layers.0.self_attn.v_proj.weight  requires grad.
# ✅ Param mask_decoder.transformer.layers.0.self_attn.v_proj.bias  requires grad.
# ✅ Param mask_decoder.transformer.layers.0.self_attn.out_proj.weight  requires grad.
# ✅ Param mask_decoder.transformer.layers.0.self_attn.out_proj.bias  requires grad.
# ✅ Param mask_decoder.transformer.layers.0.norm1.weight  requires grad.
# ✅ Param mask_decoder.transformer.layers.0.norm1.bias  requires grad.
# ✅ Param mask_decoder.transformer.layers.0.cross_attn_token_to_image.q_proj.weight  requires grad.
# ✅ Param mask_decoder.transformer.layers.0.cross_attn_token_to_image.q_proj.bias  requires grad.
# ✅ Param mask_decoder.transformer.layers.0.cross_attn_token_to_image.k_proj.weight  requires grad.
# ✅ Param mask_decoder.transformer.layers.0.cross_attn_token_to_image.k_proj.bias  requires grad.
# ✅ Param mask_decoder.transformer.layers.0.cross_attn_token_to_image.v_proj.weight  requires grad.
# ✅ Param mask_decoder.transformer.layers.0.cross_attn_token_to_image.v_proj.bias  requires grad.
# ✅ Param mask_decoder.transformer.layers.0.cross_attn_token_to_image.out_proj.weight  requires grad.
# ✅ Param mask_decoder.transformer.layers.0.cross_attn_token_to_image.out_proj.bias  requires grad.
# ✅ Param mask_decoder.transformer.layers.0.norm2.weight  requires grad.
# ✅ Param mask_decoder.transformer.layers.0.norm2.bias  requires grad.
# ✅ Param mask_decoder.transformer.layers.0.mlp.lin1.weight  requires grad.
# ✅ Param mask_decoder.transformer.layers.0.mlp.lin1.bias  requires grad.
# ✅ Param mask_decoder.transformer.layers.0.mlp.lin2.weight  requires grad.
# ✅ Param mask_decoder.transformer.layers.0.mlp.lin2.bias  requires grad.
# ✅ Param mask_decoder.transformer.layers.0.norm3.weight  requires grad.
# ✅ Param mask_decoder.transformer.layers.0.norm3.bias  requires grad.
# ✅ Param mask_decoder.transformer.layers.0.norm4.weight  requires grad.
# ✅ Param mask_decoder.transformer.layers.0.norm4.bias  requires grad.
# ✅ Param mask_decoder.transformer.layers.0.cross_attn_image_to_token.q_proj.weight  requires grad.
# ✅ Param mask_decoder.transformer.layers.0.cross_attn_image_to_token.q_proj.bias  requires grad.
# ✅ Param mask_decoder.transformer.layers.0.cross_attn_image_to_token.k_proj.weight  requires grad.
# ✅ Param mask_decoder.transformer.layers.0.cross_attn_image_to_token.k_proj.bias  requires grad.
# ✅ Param mask_decoder.transformer.layers.0.cross_attn_image_to_token.v_proj.weight  requires grad.
# ✅ Param mask_decoder.transformer.layers.0.cross_attn_image_to_token.v_proj.bias  requires grad.
# ✅ Param mask_decoder.transformer.layers.0.cross_attn_image_to_token.out_proj.weight  requires grad.
# ✅ Param mask_decoder.transformer.layers.0.cross_attn_image_to_token.out_proj.bias  requires grad.
# ✅ Param mask_decoder.transformer.layers.1.self_attn.q_proj.weight  requires grad.
# ✅ Param mask_decoder.transformer.layers.1.self_attn.q_proj.bias  requires grad.
# ✅ Param mask_decoder.transformer.layers.1.self_attn.k_proj.weight  requires grad.
# ✅ Param mask_decoder.transformer.layers.1.self_attn.k_proj.bias  requires grad.
# ✅ Param mask_decoder.transformer.layers.1.self_attn.v_proj.weight  requires grad.
# ✅ Param mask_decoder.transformer.layers.1.self_attn.v_proj.bias  requires grad.
# ✅ Param mask_decoder.transformer.layers.1.self_attn.out_proj.weight  requires grad.
# ✅ Param mask_decoder.transformer.layers.1.self_attn.out_proj.bias  requires grad.
# ✅ Param mask_decoder.transformer.layers.1.norm1.weight  requires grad.
# ✅ Param mask_decoder.transformer.layers.1.norm1.bias  requires grad.
# ✅ Param mask_decoder.transformer.layers.1.cross_attn_token_to_image.q_proj.weight  requires grad.
# ✅ Param mask_decoder.transformer.layers.1.cross_attn_token_to_image.q_proj.bias  requires grad.
# ✅ Param mask_decoder.transformer.layers.1.cross_attn_token_to_image.k_proj.weight  requires grad.
# ✅ Param mask_decoder.transformer.layers.1.cross_attn_token_to_image.k_proj.bias  requires grad.
# ✅ Param mask_decoder.transformer.layers.1.cross_attn_token_to_image.v_proj.weight  requires grad.
# ✅ Param mask_decoder.transformer.layers.1.cross_attn_token_to_image.v_proj.bias  requires grad.
# ✅ Param mask_decoder.transformer.layers.1.cross_attn_token_to_image.out_proj.weight  requires grad.
# ✅ Param mask_decoder.transformer.layers.1.cross_attn_token_to_image.out_proj.bias  requires grad.
# ✅ Param mask_decoder.transformer.layers.1.norm2.weight  requires grad.
# ✅ Param mask_decoder.transformer.layers.1.norm2.bias  requires grad.
# ✅ Param mask_decoder.transformer.layers.1.mlp.lin1.weight  requires grad.
# ✅ Param mask_decoder.transformer.layers.1.mlp.lin1.bias  requires grad.
# ✅ Param mask_decoder.transformer.layers.1.mlp.lin2.weight  requires grad.
# ✅ Param mask_decoder.transformer.layers.1.mlp.lin2.bias  requires grad.
# ✅ Param mask_decoder.transformer.layers.1.norm3.weight  requires grad.
# ✅ Param mask_decoder.transformer.layers.1.norm3.bias  requires grad.
# ✅ Param mask_decoder.transformer.layers.1.norm4.weight  requires grad.
# ✅ Param mask_decoder.transformer.layers.1.norm4.bias  requires grad.
# ✅ Param mask_decoder.transformer.layers.1.cross_attn_image_to_token.q_proj.weight  requires grad.
# ✅ Param mask_decoder.transformer.layers.1.cross_attn_image_to_token.q_proj.bias  requires grad.
# ✅ Param mask_decoder.transformer.layers.1.cross_attn_image_to_token.k_proj.weight  requires grad.
# ✅ Param mask_decoder.transformer.layers.1.cross_attn_image_to_token.k_proj.bias  requires grad.
# ✅ Param mask_decoder.transformer.layers.1.cross_attn_image_to_token.v_proj.weight  requires grad.
# ✅ Param mask_decoder.transformer.layers.1.cross_attn_image_to_token.v_proj.bias  requires grad.
# ✅ Param mask_decoder.transformer.layers.1.cross_attn_image_to_token.out_proj.weight  requires grad.
# ✅ Param mask_decoder.transformer.layers.1.cross_attn_image_to_token.out_proj.bias  requires grad.
# ✅ Param mask_decoder.transformer.final_attn_token_to_image.q_proj.weight  requires grad.
# ✅ Param mask_decoder.transformer.final_attn_token_to_image.q_proj.bias  requires grad.
# ✅ Param mask_decoder.transformer.final_attn_token_to_image.k_proj.weight  requires grad.
# ✅ Param mask_decoder.transformer.final_attn_token_to_image.k_proj.bias  requires grad.
# ✅ Param mask_decoder.transformer.final_attn_token_to_image.v_proj.weight  requires grad.
# ✅ Param mask_decoder.transformer.final_attn_token_to_image.v_proj.bias  requires grad.
# ✅ Param mask_decoder.transformer.final_attn_token_to_image.out_proj.weight  requires grad.
# ✅ Param mask_decoder.transformer.final_attn_token_to_image.out_proj.bias  requires grad.
# ✅ Param mask_decoder.transformer.norm_final_attn.weight  requires grad.
# ✅ Param mask_decoder.transformer.norm_final_attn.bias  requires grad.
# ✅ Param mask_decoder.iou_token.weight  requires grad.
# ✅ Param mask_decoder.mask_tokens.weight  requires grad.
# ✅ Param mask_decoder.output_upscaling.0.weight  requires grad.
# ✅ Param mask_decoder.output_upscaling.0.bias  requires grad.
# ✅ Param mask_decoder.output_upscaling.1.weight  requires grad.
# ✅ Param mask_decoder.output_upscaling.1.bias  requires grad.
# ✅ Param mask_decoder.output_upscaling.3.weight  requires grad.
# ✅ Param mask_decoder.output_upscaling.3.bias  requires grad.
# ✅ Param mask_decoder.output_hypernetworks_mlps.0.layers.0.weight  requires grad.
# ✅ Param mask_decoder.output_hypernetworks_mlps.0.layers.0.bias  requires grad.
# ✅ Param mask_decoder.output_hypernetworks_mlps.0.layers.1.weight  requires grad.
# ✅ Param mask_decoder.output_hypernetworks_mlps.0.layers.1.bias  requires grad.
# ✅ Param mask_decoder.output_hypernetworks_mlps.0.layers.2.weight  requires grad.
# ✅ Param mask_decoder.output_hypernetworks_mlps.0.layers.2.bias  requires grad.
# ✅ Param mask_decoder.output_hypernetworks_mlps.1.layers.0.weight  requires grad.
# ✅ Param mask_decoder.output_hypernetworks_mlps.1.layers.0.bias  requires grad.
# ✅ Param mask_decoder.output_hypernetworks_mlps.1.layers.1.weight  requires grad.
# ✅ Param mask_decoder.output_hypernetworks_mlps.1.layers.1.bias  requires grad.
# ✅ Param mask_decoder.output_hypernetworks_mlps.1.layers.2.weight  requires grad.
# ✅ Param mask_decoder.output_hypernetworks_mlps.1.layers.2.bias  requires grad.
# ✅ Param mask_decoder.output_hypernetworks_mlps.2.layers.0.weight  requires grad.
# ✅ Param mask_decoder.output_hypernetworks_mlps.2.layers.0.bias  requires grad.
# ✅ Param mask_decoder.output_hypernetworks_mlps.2.layers.1.weight  requires grad.
# ✅ Param mask_decoder.output_hypernetworks_mlps.2.layers.1.bias  requires grad.
# ✅ Param mask_decoder.output_hypernetworks_mlps.2.layers.2.weight  requires grad.
# ✅ Param mask_decoder.output_hypernetworks_mlps.2.layers.2.bias  requires grad.
# ✅ Param mask_decoder.output_hypernetworks_mlps.3.layers.0.weight  requires grad.
# ✅ Param mask_decoder.output_hypernetworks_mlps.3.layers.0.bias  requires grad.
# ✅ Param mask_decoder.output_hypernetworks_mlps.3.layers.1.weight  requires grad.
# ✅ Param mask_decoder.output_hypernetworks_mlps.3.layers.1.bias  requires grad.
# ✅ Param mask_decoder.output_hypernetworks_mlps.3.layers.2.weight  requires grad.
# ✅ Param mask_decoder.output_hypernetworks_mlps.3.layers.2.bias  requires grad.
# ✅ Param mask_decoder.iou_prediction_head.layers.0.weight  requires grad.
# ✅ Param mask_decoder.iou_prediction_head.layers.0.bias  requires grad.
# ✅ Param mask_decoder.iou_prediction_head.layers.1.weight  requires grad.
# ✅ Param mask_decoder.iou_prediction_head.layers.1.bias  requires grad.
# ✅ Param mask_decoder.iou_prediction_head.layers.2.weight  requires grad.
# ✅ Param mask_decoder.iou_prediction_head.layers.2.bias  requires grad.

# %%
def one_image_predict(image_masks, gt_masks, gt_bboxes, image_embedding, original_image_size, input_size, negative_mask, input_image, model):
    image_loss=[]
    ce_loss = 0.0
    boxes, masks, coords, coords_labels = [], [], [], []
    gt_rle_to_masks, mask_areas = [], []

    for k in image_masks: 
        prompt_box = np.array(gt_bboxes[k])
        box = predictor.transform.apply_boxes(prompt_box, original_image_size)
        box_torch = torch.as_tensor(box, dtype=torch.float, device=device)
        boxes.append(box_torch)

        # process masks
        rle_to_mask = maskUtils.decode(gt_masks[k])
        gt_rle_to_masks.append(torch.from_numpy(rle_to_mask).to(device))
        mask_input_torch = torch.as_tensor(rle_to_mask, dtype=torch.float, device=predictor.device).unsqueeze(0)#.unsqueeze(0)
        mask_input_torch = F.interpolate(mask_input_torch.unsqueeze(0), size=(256, 256), mode='bilinear', align_corners=False)
        masks.append(mask_input_torch.squeeze(0))
        mask_areas.append(np.sum(rle_to_mask))

        # process coords and labels
        x_min, y_min, x_max, y_max = gt_bboxes[k]
        x_min, y_min, x_max, y_max = map(int, [x_min, y_min, x_max, y_max])
        point_coords = np.array([(gt_bboxes[k][2]+gt_bboxes[k][0])/2.0, (gt_bboxes[k][3]+gt_bboxes[k][1])/2.0])
        point_labels = np.array([1])
        point_coords = predictor.transform.apply_coords(point_coords, original_image_size)
        coords_torch = torch.as_tensor(point_coords, dtype=torch.float, device=predictor.device).unsqueeze(0)
        labels_torch = torch.as_tensor(point_labels, dtype=torch.int, device=predictor.device)
        coords.append(coords_torch)
        coords_labels.append(labels_torch)

    boxes = torch.stack(boxes, dim=0)
    masks = torch.stack(masks, dim=0)
    coords = torch.stack(coords, dim=0)
    coords_labels = torch.stack(coords_labels, dim=0)
    points = (coords, coords_labels)
    gt_rle_to_masks = torch.stack(gt_rle_to_masks, dim=0)
    
    sparse_embeddings, dense_embeddings = model.prompt_encoder(
      points=None,
      boxes=boxes,
      masks=None, 
    )

    del box_torch, coords_torch, labels_torch
    torch.cuda.empty_cache()
    
    low_res_masks, iou_predictions = model.mask_decoder(
    image_embeddings=image_embedding,
    image_pe=model.prompt_encoder.get_dense_pe(),
    sparse_prompt_embeddings=sparse_embeddings,
    dense_prompt_embeddings=dense_embeddings,
    multimask_output=False, # True value works better for ambiguous prompts (single points)
    )

    # plt.imshow(low_res_masks[0][0].detach().cpu().numpy())
    # plt.show()
    # plt.close()
    
    pred_masks = model.postprocess_masks(low_res_masks, input_size, original_image_size).to(device)
    threshold_mask = torch.sigmoid(pred_masks)# - 0.5) #- model.mask_threshold)
    gt_threshold_mask = torch.as_tensor(gt_rle_to_masks, dtype=torch.float32) 
    numpy_gt_threshold_mask = gt_threshold_mask.contiguous().detach().cpu().numpy()
    mask_result = torch.squeeze(threshold_mask, dim=1).detach().cpu().numpy()

    # compute weighted dice loss (smaller weights on smaller objects)
    focal = loss.focal_loss_per_mask_pair(torch.squeeze(threshold_mask, dim=1), gt_threshold_mask, mask_areas)
    dice = loss.dice_loss_per_mask_pair(torch.squeeze(threshold_mask, dim=1), gt_threshold_mask, mask_areas, negative_mask) 
    image_loss.append(20 * focal + dice ) # used in SAM paper

    del threshold_mask 
    del numpy_gt_threshold_mask 
    del low_res_masks, iou_predictions 
    del pred_masks, gt_threshold_mask
    del rle_to_mask
    torch.cuda.empty_cache()

    image_loss = torch.stack(image_loss)
    image_loss = torch.mean(image_loss) #* loss_scaling_factor
    
    # fig, axs = plt.subplots(1, 3, figsize=(40, 20))
    # axs[0].imshow(input_image) 
    # axs[0].set_title(f'{k.split(".")[0]}', fontsize=40)
    
    # axs[1].imshow(input_image)
    # predict.show_masks(mask_result, axs[1], random_color=False)
    # axs[1].set_title('Predicted masks', fontsize=40)
    
    # axs[2].imshow(input_image) 
    # predict.show_masks(gt_rle_to_masks.detach().cpu().numpy(), axs[2], random_color=False)
    # axs[2].set_title('Ground truth masks', fontsize=40)
    
    # plt.show()
    # plt.close()

    return image_loss

# %%
import torch
import numpy as np
from tqdm import tqdm

def train_validate_step(model, dataloader, input_dir, gt_masks, gt_bboxes, device, optimizer=None, mode='train'):
    assert mode in ['train', 'validate'], "Mode must be 'train' or 'validate'"
    losses = []

    for inputs in tqdm(dataloader, desc=f'{mode[0].upper()+mode[1:]} Progress', bar_format='{l_bar}{bar:10}{r_bar}{bar:-10b}'):
        batch_loss = 0.0
        global batch_idx
        current_iter = epoch * len(dataloader) + batch_idx
        batch_idx = batch_idx + 1
        batch_size = len(inputs['image']) # sometimes, at the last iteration, there are fewer images than batch size
        for i in range(batch_size):
            image_masks = [k for k in gt_masks.keys() if k.startswith(inputs['image_id'][i])]
            idd = inputs['image_id'][i]
            input_image = torch.as_tensor(inputs['image'][i], dtype=torch.float, device=predictor.device) # (B, C, 1024, 1024)
            image = cv2.imread(input_dir+inputs['image_id'][i])
            image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
            original_image_size = image.shape[:-1]
            input_size = (1024, 1024)

            # IMAGE ENCODER
            image_embedding = model.image_encoder(input_image)
               
            # negative_mask has the size of the image
            negative_mask = np.where(image>0, True, False)
            negative_mask = torch.from_numpy(negative_mask)  
            negative_mask = negative_mask.permute(2, 0, 1)
            negative_mask = negative_mask[0]
            negative_mask = negative_mask.unsqueeze(0).unsqueeze(0)
            negative_mask = negative_mask.to(device)
            
            # RUN PREDICTION ON IMAGE
            if len(image_masks)>0:
                batch_loss += (one_image_predict(image_masks, gt_masks, gt_bboxes, image_embedding, 
                                                 original_image_size, input_size, negative_mask, image, model)) 
            else:
                print(f"{idd} has no annotations❗️")
        if mode == 'train':
            # for name, parameter in model.named_parameters():
            #     if parameter.grad is not None: 
            #         grad_norm = parameter.grad.norm()
            #         if grad_norm < 1e-8: 
            #             print(f'❗️Layer {name} has vanishing gradients: {grad_norm}')
            # for name, parameter in model.named_parameters():
            # 	if parameter.grad is not None:
            # 		print(name, parameter.grad.abs().mean())
                    
            optimizer.zero_grad()
            batch_loss.backward()
            optimizer.step()
                
            # if current_iter < warmup_iters:
            #     scheduler_warmup.step()
            # elif batch_idx % steps_per_epoch == 0:
            #     scheduler.step()

            del image_embedding, negative_mask, input_image, idd, image
            torch.cuda.empty_cache()

        losses.append(batch_loss.item()/batch_size)#/loss_scaling_factor)
            
    return np.mean(losses), model

# %%
import matplotlib.patches as patches

train_losses = []
valid_losses = []
num_epochs = 10
best_valid_loss = float('inf')
n_epochs_stop = float('inf') #5 + num_epochs/10

for epoch in range(num_epochs):
    batch_idx = 0.0
    # train
    mobile_sam_model.train()
    epoch_loss, model = train_validate_step(
        mobile_sam_model, 
        train_dataloader, 
        train_dir, 
        train_gt_masks, 
        train_bboxes, 
        device, 
        optimizer, 
        mode='train')
    train_losses.append(epoch_loss)
    
    # validate
    mobile_sam_model.eval()
    with torch.no_grad():
        epoch_val_loss, model = train_validate_step(
            mobile_sam_model, 
            val_dataloader, 
            valid_dir, 
            val_gt_masks, 
            val_bboxes, 
            device, 
            optimizer, 
            mode='validate')
        valid_losses.append(epoch_val_loss)
        
    # early stopping
    if epoch_val_loss < best_valid_loss:
        best_valid_loss = epoch_val_loss
        best_model = model
        epochs_no_improve = 0
    else:
        epochs_no_improve += 1
        if epochs_no_improve == n_epochs_stop:
            print("Early stopping initiated.")
            early_stop = True
            break
    if epoch % 20 == 0:
        torch.save(best_model.state_dict(), f'ft_mobile_sam_final.pth')


    # # Logging
    if use_wandb:
        wandb.log({'epoch training loss': epoch_loss, 'epoch validation loss': epoch_val_loss})

    print(f'EPOCH: {epoch}. Training loss: {epoch_loss}')
    print(f'EPOCH: {epoch}. Validation loss: {epoch_val_loss}.')

if use_wandb:
    wandb.run.summary["batch_size"] = batch_size
    wandb.run.summary["num_epochs"] = num_epochs
    wandb.run.summary["learning rate"] = lr
    wandb.run.summary["weight_decay"] = wd
    wandb.run.summary["loss_scaling_factor"] = loss_scaling_factor
    wandb.run.summary["# train images"] = len(train_dataloader.dataset)
    wandb.run.summary["# validation images"] = len(val_dataloader.dataset)

    run.finish()
    
torch.save(best_model.state_dict(), f'ft_mobile_sam_final.pth')
# Out:
# Train Progress: 100%|██████████| 5/5 [00:17<00:00,  3.46s/it]
# Validate Progress: 100%|██████████| 3/3 [00:07<00:00,  2.59s/it]
# EPOCH: 0. Training loss: 0.20040581226348878
# EPOCH: 0. Validation loss: 0.14134134352207184.
# Train Progress: 100%|██████████| 5/5 [00:17<00:00,  3.41s/it]
# Validate Progress: 100%|██████████| 3/3 [00:08<00:00,  2.92s/it]
# EPOCH: 1. Training loss: 0.20040581822395326
# EPOCH: 1. Validation loss: 0.14134134352207184.
# Train Progress:  20%|██        | 1/5 [00:04<00:16,  4.22s/it]
#
# KeyboardInterrupt

# %%
import sys
import PIL
from PIL import Image

check_orig = False
if check_orig:
    sys.path.append('/workspace/raid/OM_DeepLearning/MobileSAM-master/')
    import mobile_sam
    from mobile_sam import sam_model_registry as orig_mobile_sam_model_registry, \
                           SamAutomaticMaskGenerator as orig_mobile_SamAutomaticMaskGenerator, \
                           SamPredictor as orig_mobile_SamPredictor
    
    # orig_mobile_sam_checkpoint = "/workspace/raid/OM_DeepLearning/XMM_OM_code_git/ft_mobile_sam_final.pth"
    orig_mobile_sam_checkpoint = "/workspace/raid/OM_DeepLearning/MobileSAM-master/weights/mobile_sam.pt"
    orig_mobile_sam_model = orig_mobile_sam_model_registry["vit_t"](checkpoint=orig_mobile_sam_checkpoint)
    orig_mobile_sam_model.to(device);
    orig_mobile_sam_model.eval();
    
    mobile_sam_model.eval();
    predictor = orig_mobile_SamPredictor(mobile_sam_model)
    
    valid_losses = []
    with torch.no_grad():
        epoch_val_loss, _ = train_validate_step(orig_mobile_sam_model, val_dataloader, val_gt_masks, val_bboxes, device, optimizer, mode='validate')
        valid_losses.append(epoch_val_loss)
    print(f'EPOCH: {epoch}. Validation loss: {epoch_val_loss}.')

# %%
# from IPython.display import display
# display(dot)

# %%
# import json
# import graphviz

# json_file_path = './graph_0_summary_598a07b5e588b04c9de6.graph.json'

# with open(json_file_path, 'r') as file:
#     model_data = json.load(file)

# dot = graphviz.Digraph(comment='Model Visualization')

# for node in model_data['nodes']:
#     label = f"{node['name']}\n{node['class_name']}"
#     dot.node(str(node['id']), label=label)
# dot.render('output', view=False)

# %%
# plt.plot(list(range(len(losses))), losses)
# plt.title('Mean epoch loss \n mask with sigmoid')
# plt.xlabel('Epoch Number')
# plt.ylabel('Loss')
# plt.savefig('loss_mask_sigmoid_training.png')
# plt.show()
# plt.close()
